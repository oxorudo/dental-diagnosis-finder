# %%
# %pip install selenium

# %% [markdown]
# ---
#
# ## 구글 시트 불러오기

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
from tqdm import tqdm

# 수정된 부분

# %%
# Google 스프레드시트 API 인증 범위 설정
scope = ["https://spreadsheets.google.com/feeds"]

# 서비스 계정 JSON 키 파일 경로 설정
json_key_path = "key.json"

# 인증 정보 로드
credential = ServiceAccountCredentials.from_json_keyfile_name(json_key_path, scope)
gc = gspread.authorize(credential)

# 스프레드시트 URL 설정
spreadsheet_url = "https://docs.google.com/spreadsheets/d/1PzFuHuF2DvMPdSI-TK4Kq5LjPwyGzIxH3Q0Drnqft20/edit?usp=sharing"

# URL을 통해 스프레드시트 열기
doc = gc.open_by_url(spreadsheet_url)

# 시트 선택하기
sheet_action = doc.worksheet("행위별 Category")

# 데이터 프레임으로 변환하기
df_action = pd.DataFrame(sheet_action.get_all_values())

# 첫 번째 행을 컬럼명으로 설정하고 나머지 데이터로 변환
df_action.rename(columns=df_action.iloc[0], inplace=True)
df_action.drop(df_action.index[0], inplace=True)

# %%
df_action
# Out:
#       보험 청구 Category         세부 청구 항목 (키워드)  \
# 1    1. 청구 기초 및 기본진료         구내염처치, 단순염증 처치
# 2    1. 청구 기초 및 기본진료           기본진료 종류 및 상병
# 3    1. 청구 기초 및 기본진료        기본진료시 항생제 처방 상병
# 4    1. 청구 기초 및 기본진료  상세불명 vs 기타 명시된 상병명 차이
# 5    1. 청구 기초 및 기본진료                   전달마취
# ..               ...                    ...
# 107           8. 턱관절        악관절 탈구 비관혈적 정복술
# 108           8. 턱관절               악관절고착해소술
# 109           8. 턱관절   악관절자극요법 (단순, 전기, 복합)
# 110           8. 턱관절            측두하악장애 분석검사
# 111           8. 턱관절             파노라마 촬영 특수
#
# URL  (tripletclover.com)  \
# 1    https://tripletclover.com/%ea%b5%ac%eb%82%b4%e...
# 2    https://tripletclover.com/%ea%b8%b0%eb%b3%b8%e...
# 3    https://tripletclover.com/%ea%b8%b0%eb%b3%b8-%...
# 4    https://tripletclover.com/%ec%83%81%ec%84%b8%e...
# 5    https://tripletclover.com/%ec%a0%84%eb%8b%ac%e...
# ..                                                 ...
# 107  https://tripletclover.com/%ec%95%85%ea%b4%80%e...
# 108  https://tripletclover.com/%ec%95%85%ea%b4%80%e...
# 109  https://tripletclover.com/%ec%95%85%ea%b4%80%e...
# 110  https://tripletclover.com/%ec%b8%a1%eb%91%90%e...
# 111  https://tripletclover.com/%ed%8c%8c%eb%85%b8%e...
#
#                                                     코드 상병명 없음 휴먼 체크
# 1    B00.2, K05.00, K05.10, K05.11, K05.12, K05.18,...
# 2    K01.1, K02.0, K02.1, K02.2, K02.3, K02.5, K02....
# 3    K01.18, K04.7, K05.12, K05.13, K05.18, K05.20,...
# 4             K02.0, K02.1, K02.2, K02.3, K02.5, K02.8
# 5    K00.63, K00.68, K02.1, K02.2, K04.00, K04.01, ...           완료
# ..                                                 ...          ...
# 107                                      S03.0, K07.62           수정
# 108                                     K07.64, K07.68
# 109  K07.60, K07.62, K07.63, K07.64, K07.65, K07.66...
# 110                                             상병명 없음           완료
# 111  K07.60, K07.61, K07.62, K07.63, K07.64, K07.65...
#
# [111 rows x 5 columns]

# %%
df_action
urls = df_action["\x08URL  (tripletclover.com)"].tolist()

# %% [markdown]
# ---
# ## 크롤링

# %%
import re
import requests
from bs4 import BeautifulSoup
import json  # 파일 저장을 위한 모듈


def crawling_code(urls):
    not_found_urls = []  # 상병명을 찾지 못한 URL들을 저장할 리스트
    extracted_codes_list = []  # 각 URL에서 추출된 코드를 저장할 리스트

    for url in urls:
        # 페이지 소스를 가져옴
        response = requests.get(url)
        html = response.text

        # BeautifulSoup으로 HTML 파싱
        soup = BeautifulSoup(html, "html.parser")

        # id 속성에 "상병명"이 포함된 h2 태그 찾기 ("적용-가능-상병명-목록" 등도 포함되도록)
        start_section = soup.find("h2", id=lambda x: "상병명" in x if x else False)

        if start_section:
            # 알파벳숫자.숫자 패턴을 찾기 위한 정규 표현식
            pattern = re.compile(r"[A-Za-z]+\d+\.\d+")

            # wp-block-list 클래스를 가진 모든 ul, ol 태그 찾기
            wp_block_lists = start_section.find_all_next(
                ["ul", "ol"], class_="wp-block-list"
            )

            # p 태그와 ul 태그에서 패턴에 맞는 텍스트 추출
            extracted_codes = set()

            for wp_block_list in wp_block_lists:
                for li in wp_block_list.find_all("li"):
                    # strong 태그 안에 있는 코드 먼저 확인
                    strong_tag = li.find("strong")
                    if strong_tag:
                        match = pattern.search(strong_tag.text)
                    else:
                        # strong 태그가 없는 경우 li 텍스트에서 패턴 추출
                        match = pattern.search(li.text)

                    if match:
                        extracted_codes.add(match.group())

            # p 태그에서도 같은 패턴을 추출
            for p_tag in start_section.find_all_next("p"):
                match = pattern.search(p_tag.text)
                if match:
                    extracted_codes.add(match.group())

            # 추출된 코드 정렬
            sorted_codes = sorted(extracted_codes)

            # 추출된 코드 출력
            print("Extracted codes:", sorted_codes)
            print("Number of extracted codes:", len(sorted_codes))
            extracted_codes_list.append(
                ", ".join(sorted_codes) if sorted_codes else "코드 없음"
            )

        else:
            # 상병명을 찾지 못한 URL을 저장
            print(f"No section with '상병명' found in {url}")
            not_found_urls.append(url)
            extracted_codes_list.append("상병명 없음")  # 못찾으면 코드 없음으로 기록

    # 상병명을 찾지 못한 URL을 파일로 저장
    if not_found_urls:
        with open("not_found_urls.json", "w") as f:
            json.dump(not_found_urls, f, ensure_ascii=False, indent=4)

    # 상병명을 찾지 못한 URL과 크롤링된 코드 리스트 반환
    return not_found_urls, extracted_codes_list

# %%
not_found, extracted_codes = crawling_code(urls)

# 결과 출력
print("URLs where '상병명' was not found:", not_found)
print("Extracted codes for each URL:", extracted_codes)
# Out:
# Extracted codes: ['B00.2', 'B37.0', 'K05.00', 'K05.10', 'K05.11', 'K05.12', 'K05.18', 'K05.19', 'K05.22', 'K05.32', 'K12.0', 'K12.1', 'K13.1', 'S00.5']
# Number of extracted codes: 14
# Extracted codes: ['J01.00', 'K01.1', 'K01.10', 'K01.11', 'K01.12', 'K01.13', 'K01.14', 'K01.15', 'K01.163', 'K01.173', 'K02.0', 'K02.1', 'K02.2', 'K02.3', 'K02.5', 'K02.8', 'K03.00', 'K03.01', 'K03.10', 'K03.18', 'K03.2', 'K03.80', 'K04.00', 'K04.7', 'K05.1', 'K05.10', 'K05.11', 'K05.12', 'K05.13', 'K05.18', 'K05.2', 'K05.20', 'K05.21', 'K05.22', 'K05.28', 'K05.29', 'K05.30', 'K05.31', 'K07.6', 'K07.60', 'K07.61', 'K07.62', 'K07.63', 'K07.64', 'K07.65', 'K07.66', 'K07.68', 'K07.69']
# Number of extracted codes: 48
# Extracted codes: ['J01.00', 'K01.10', 'K01.11', 'K01.12', 'K01.13', 'K01.14', 'K01.15', 'K01.163', 'K01.173', 'K01.18', 'K04.7', 'K05.12', 'K05.13', 'K05.18', 'K05.20', 'K05.21', 'K05.22', 'K05.28', 'K05.29', 'K05.30', 'K05.31', 'K07.60', 'K07.61', 'K07.62', 'K07.63', 'K07.64', 'K07.65', 'K07.66', 'K07.68', 'K07.69']
# Number of extracted codes: 30
# Extracted codes: ['K02.0', 'K02.1', 'K02.2', 'K02.3', 'K02.5', 'K02.8', 'K02.9']
# Number of extracted codes: 7
# No section with '상병명' found in https://tripletclover.com/%ec%a0%84%eb%8b%ac%eb%a7%88%ec%b7%a8-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80%ec%9d%b4%eb%93%9c/
# Extracted codes: ['K00.63', 'K00.68', 'K01.173', 'K02.1', 'K02.2', 'K04.00', 'K04.01', 'K04.80', 'S02.55']
# Number of extracted codes: 9
# Extracted codes: ['K00.63', 'K00.68', 'K01.173', 'K02.1', 'K02.2', 'K04.00', 'K04.01', 'K04.80', 'S02.55']
# Number of extracted codes: 9
# No section with '상병명' found in https://tripletclover.com/%ec%b9%a8%ec%9c%a4%eb%a7%88%ec%b7%a8-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80%ec%9d%b4%eb%93%9c/
# Extracted codes: ['K00.00', 'K00.63', 'K00.68', 'K01.163', 'K01.173', 'K01.18', 'K08.1', 'K08.88', 'S02.5']
# Number of extracted codes: 9
# Extracted codes: ['K00.29', 'K01.163', 'K01.173', 'K01.18', 'K04.80', 'K07.35', 'S02.55']
# Number of extracted codes: 7
# No section with '상병명' found in https://tripletclover.com/%ea%b5%90%ec%9d%b5%ec%b4%ac%ec%98%81-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80%ec%9d%b4%eb%93%9c/
# Extracted codes: ['K01.1', 'K04.8', 'K05.3', 'K10.0', 'K10.8', 'S04.3', 'T85.6']
# Number of extracted codes: 7
# Extracted codes: ['K02.0', 'K03.00', 'K03.10', 'K03.2', 'K03.80', 'K05.18', 'K06.00']
# Number of extracted codes: 7
# Extracted codes: []
# Number of extracted codes: 0
# Extracted codes: ['K02.1', 'K02.2', 'K02.8']
# Number of extracted codes: 3
# Extracted codes: ['K05.30', 'K05.31', 'K06.20', 'K07.2', 'K07.3', 'K07.4', 'S02.5', 'S02.52', 'S02.53', 'S02.54', 'S02.55', 'S02.56', 'S03.2', 'S03.20', 'S03.21', 'S03.22']
# Number of extracted codes: 16
# Extracted codes: ['T85.6', 'Z46.3']
# Number of extracted codes: 2
# Extracted codes: ['K02.8', 'K05.3', 'T85.6', 'Z46.3']
# Number of extracted codes: 4
# Extracted codes: ['K02.8', 'K05.3', 'T85.6', 'Z46.3']
# Number of extracted codes: 4
# Extracted codes: ['K02.1', 'K02.2', 'K02.8', 'K04.1', 'K04.9', 'S02.52', 'S02.59']
# Number of extracted codes: 7
# Extracted codes: ['K02.8', 'K05.3', 'T85.6', 'Z46.3']
# Number of extracted codes: 4
# Extracted codes: ['K00.68', 'K02.1', 'Z29.8']
# Number of extracted codes: 3
# Extracted codes: ['K02.1', 'K02.2', 'K02.8', 'K02.9', 'K03.10', 'K03.18']
# Number of extracted codes: 6
# Extracted codes: ['K03.10', 'K03.18', 'K03.80', 'K06.00', 'K06.01', 'K06.09', 'Z29.8']
# Number of extracted codes: 7
# Extracted codes: ['K03.10', 'K03.18', 'K03.80', 'K06.00', 'K06.01']
# Number of extracted codes: 5
# Extracted codes: ['K02.1', 'K02.2', 'K02.8', 'K02.9']
# Number of extracted codes: 4
# Extracted codes: ['K02.1', 'K02.2', 'K02.3', 'K02.8', 'K03.10', 'K03.18']
# Number of extracted codes: 6
# Extracted codes: ['K02.1', 'K02.2', 'K02.8', 'K02.9', 'K03.10', 'K03.18', 'T85.6', 'Z97.2']
# Number of extracted codes: 8
# Extracted codes: ['K05.00', 'K05.08', 'K05.09', 'K05.10', 'K05.18']
# Number of extracted codes: 5
# Extracted codes: ['K00.68', 'K02.1', 'Z29.8']
# Number of extracted codes: 3
# No section with '상병명' found in https://tripletclover.com/%ec%b9%98%ec%88%98-%eb%b3%b5%ec%a1%b0-%eb%b0%8f-%ec%83%81%eb%b3%91%eb%aa%85/
# Extracted codes: ['K02.1', 'K02.2', 'K02.5', 'K02.8']
# Number of extracted codes: 4
# Extracted codes: ['T85.6']
# Number of extracted codes: 1
# Extracted codes: ['K04.5', 'K04.62', 'K04.7', 'K04.80']
# Number of extracted codes: 4
# Extracted codes: ['K02.5', 'K04.01', 'K04.1', 'K04.2', 'K04.3', 'K04.4', 'K04.5', 'K04.62', 'K04.7', 'K04.80', 'K04.9', 'S02.54', 'S02.55', 'S02.56', 'S03.20', 'S03.28']
# Number of extracted codes: 16
# Extracted codes: ['K02.5', 'K04.01', 'K04.1', 'K04.2', 'K04.3', 'K04.4', 'K04.5', 'K04.62', 'K04.7', 'K04.80', 'K04.9', 'S02.54', 'S02.55', 'S02.56', 'S03.20', 'S03.28']
# Number of extracted codes: 16
# Extracted codes: ['K02.5', 'K04.01', 'K04.1', 'K04.2', 'K04.3', 'K04.4', 'K04.5', 'K04.62', 'K04.7', 'K04.80', 'K04.9', 'S02.54', 'S02.55', 'S02.56', 'S03.20', 'S03.28']
# Number of extracted codes: 16
# Extracted codes: ['K02.5', 'K04.01', 'K04.1', 'K04.2', 'K04.3', 'K04.4', 'K04.9', 'S02.54', 'S02.55', 'S02.56']
# Number of extracted codes: 10
# Extracted codes: ['K02.5', 'K04.01', 'K04.1', 'K04.2', 'K04.3', 'K04.4', 'K04.5', 'K04.62', 'K04.7', 'K04.80', 'K04.9', 'S02.54', 'S02.55', 'S02.56', 'S03.20', 'S03.28']
# Number of extracted codes: 16
# Extracted codes: ['K02.5', 'K04.01', 'K04.1', 'K04.2', 'K04.3', 'K04.4', 'K04.5', 'K04.62', 'K04.7', 'K04.80', 'K04.9', 'S02.54', 'S02.55', 'S02.56', 'S03.20', 'S03.28']
# Number of extracted codes: 16
# Extracted codes: ['K04.1', 'K04.4', 'K04.62', 'K04.7']
# Number of extracted codes: 4
# Extracted codes: ['K04.5', 'K04.62', 'K04.7', 'K04.80']
# Number of extracted codes: 4
# Extracted codes: ['K02.5', 'K04.01', 'K04.09', 'K04.2', 'K04.3']
# Number of extracted codes: 5
# Extracted codes: ['K02.5', 'S02.5', 'S03.2', 'T85.6']
# Number of extracted codes: 4
# Extracted codes: ['K05.30', 'K05.31', 'S02.88', 'S03.20', 'S03.22', 'S03.28']
# Number of extracted codes: 6
# Extracted codes: ['K05.2', 'K05.20', 'K05.21', 'K05.22', 'K05.28', 'K05.29', 'K05.30', 'K05.31', 'K05.32', 'K05.38', 'K05.39']
# Number of extracted codes: 11
# Extracted codes: ['K05.0', 'K05.00', 'K05.1', 'K05.10', 'K05.11', 'K05.12', 'K05.13', 'K05.18', 'K05.19', 'K05.2', 'K05.20', 'K05.21', 'K05.22', 'K05.28', 'K05.29', 'K05.3', 'K05.30', 'K05.31', 'K05.32', 'K05.38', 'K05.39', 'K05.4', 'K05.5', 'K05.6']
# Number of extracted codes: 24
# Extracted codes: ['K05.0', 'K05.00', 'K05.1', 'K05.10', 'K05.11', 'K05.12', 'K05.13', 'K05.18', 'K05.19', 'K05.2', 'K05.20', 'K05.21', 'K05.22', 'K05.28', 'K05.29', 'K05.3', 'K05.30', 'K05.31', 'K05.32', 'K05.38', 'K05.39', 'K05.4', 'K05.5', 'K05.6']
# Number of extracted codes: 24
# Extracted codes: ['K05.0', 'K05.00', 'K05.1', 'K05.10', 'K05.11', 'K05.12', 'K05.13', 'K05.18', 'K05.19', 'K05.2', 'K05.20', 'K05.21', 'K05.22', 'K05.28', 'K05.29', 'K05.3', 'K05.30', 'K05.31', 'K05.32', 'K05.38', 'K05.39', 'K05.4', 'K05.5', 'K05.6']
# Number of extracted codes: 24
# Extracted codes: ['K05.30', 'K05.31', 'K05.38', 'K05.39']
# Number of extracted codes: 4
# Extracted codes: ['K05.30', 'K05.31', 'K05.38', 'K05.39']
# Number of extracted codes: 4
# No section with '상병명' found in https://tripletclover.com/%ec%b9%98%ec%9d%80%eb%b0%95%eb%a6%ac%ec%86%8c%ed%8c%8c%ec%88%a0-%ea%b0%84%eb%8b%a8-vs-%eb%b3%b5%ec%9e%a1-%eb%b9%84%ea%b5%90-%ec%a0%95%eb%a6%ac/
# No section with '상병명' found in https://tripletclover.com/%ec%b9%98%ec%9d%80%ed%8c%90%ec%a0%88%ec%a0%9c%ec%88%a0-%ec%b9%98%ea%b4%80%ed%99%95%ec%9e%a5%ec%88%a0-%ec%b9%98%ec%9d%80%ec%a0%88%ec%a0%9c%ec%88%a0-%eb%b9%84%ea%b5%90/
# Extracted codes: ['K05.20', 'K05.21', 'K05.22', 'K05.28', 'K05.29', 'K05.30', 'K05.31', 'K05.32', 'K05.38', 'K05.39', 'K05.4', 'K05.5', 'K05.6']
# Number of extracted codes: 13
# Extracted codes: ['K05.30', 'K05.31', 'K05.38', 'K05.39']
# Number of extracted codes: 4
# Extracted codes: ['K05.00', 'K05.08', 'K05.09', 'K05.10', 'K05.11', 'K05.12', 'K05.13', 'K05.18', 'K05.19', 'K05.20', 'K05.21', 'K05.22', 'K05.28', 'K05.29', 'K05.30', 'K05.31', 'K05.32', 'K05.38', 'K05.39', 'K05.4', 'K05.5', 'K05.6']
# Number of extracted codes: 22
# Extracted codes: ['K05.30', 'K05.31', 'K05.38', 'K05.5']
# Number of extracted codes: 4
# Extracted codes: ['K05.30', 'K05.31', 'K05.38', 'K05.5']
# Number of extracted codes: 4
# Extracted codes: ['K06.0', 'K06.00', 'K06.01', 'K06.1', 'K06.10', 'K06.18', 'K06.2', 'K06.8', 'K06.9', 'K08.20', 'M26.09', 'T81.8']
# Number of extracted codes: 12
# Extracted codes: ['K06.8', 'K06.9', 'K08.20', 'M26.09', 'T81.8']
# Number of extracted codes: 5
# Extracted codes: ['K10.0', 'K10.8']
# Number of extracted codes: 2
# Extracted codes: ['K00.10', 'K00.11', 'K00.12', 'K00.19', 'K01.18']
# Number of extracted codes: 5
# Extracted codes: ['S01.51', 'S01.52', 'S01.53', 'S01.54']
# Number of extracted codes: 4
# Extracted codes: ['K04.7', 'K05.20', 'K10.2', 'K12.2']
# Number of extracted codes: 4
# Extracted codes: ['K00.20', 'K00.44', 'K03.4', 'K03.5', 'K07.3', 'S02.5']
# Number of extracted codes: 6
# Extracted codes: ['K01.0', 'K01.10', 'K01.11', 'K01.12', 'K01.13', 'K01.14', 'K01.15', 'K01.163', 'K01.169', 'K01.173', 'K01.179', 'K01.18', 'K01.19']
# Number of extracted codes: 13
# Extracted codes: ['K00.1', 'K00.10', 'K00.11', 'K00.12', 'K00.19', 'K00.2', 'K00.63', 'K01.163', 'K02.2', 'K03.5', 'K08.3', 'S02.5', 'S02.55', 'S02.56', 'S02.57', 'S02.59', 'S03.2', 'S03.21', 'S03.22', 'S03.28']
# Number of extracted codes: 20
# Extracted codes: ['K01.0', 'K01.10', 'K01.11', 'K01.12', 'K01.13', 'K01.14', 'K01.15', 'K01.163', 'K01.169', 'K01.173', 'K01.179', 'K01.18', 'K01.19', 'K07.35']
# Number of extracted codes: 14
# No section with '상병명' found in https://tripletclover.com/%ec%83%81%ea%b3%a0%ec%a0%95%ec%9e%a5%ec%b9%98%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80/
# No section with '상병명' found in https://tripletclover.com/%ec%84%a4%ec%86%8c%eb%8c%80-%ec%84%b1%ed%98%95%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80/
# Extracted codes: ['K01.163', 'K01.173', 'K01.18', 'K01.19', 'K04.7', 'K04.80', 'K05.20', 'K05.31', 'K08.3', 'K10.3', 'S02.55', 'S02.56', 'S02.57', 'Z48.0']
# Number of extracted codes: 14
# Extracted codes: ['K04.7', 'K04.80', 'K04.81', 'K04.82', 'K04.89', 'K05.20', 'K10.2', 'K12.2', 'Z48.0']
# Number of extracted codes: 9
# Extracted codes: ['D10.3', 'K04.7', 'K05.20', 'K10.2', 'K10.3', 'K12.2']
# Number of extracted codes: 6
# Extracted codes: ['Y60.0']
# Number of extracted codes: 1
# Extracted codes: ['K01.0', 'K01.10', 'K01.11', 'K01.12', 'K01.13', 'K01.14', 'K01.15', 'K01.163', 'K01.169', 'K01.173', 'K01.179', 'K01.18', 'K01.19']
# Number of extracted codes: 13
# Extracted codes: ['K00.63', 'K00.68', 'K00.69', 'K02.8', 'K03.5', 'K04.7']
# Number of extracted codes: 6
# Extracted codes: ['S01.4', 'S01.40', 'S01.41', 'S01.42', 'S01.48', 'S01.50']
# Number of extracted codes: 6
# Extracted codes: ['K02.2', 'K02.8', 'K06.18', 'K06.19', 'S02.54', 'S02.56']
# Number of extracted codes: 6
# Extracted codes: ['K04.80', 'K04.81', 'K04.82', 'K04.89']
# Number of extracted codes: 4
# Extracted codes: ['K04.5', 'K04.62', 'K04.7', 'K04.80', 'K04.81', 'K04.82']
# Number of extracted codes: 6
# Extracted codes: ['K04.5', 'K04.62', 'K04.7', 'K04.80', 'K04.9', 'S03.22']
# Number of extracted codes: 6
# Extracted codes: ['K05.11', 'K05.30', 'K05.31', 'K05.38', 'K06.10', 'K06.18', 'K06.19']
# Number of extracted codes: 7
# Extracted codes: ['K00.68', 'K02.1', 'K05.22', 'K06.18']
# Number of extracted codes: 4
# Extracted codes: ['K08.81']
# Number of extracted codes: 1
# No section with '상병명' found in https://tripletclover.com/%ed%98%91%ec%88%9c%ec%86%8c%eb%8c%80-%ec%84%a4%ec%86%8c%eb%8c%80-%ec%84%b1%ed%98%95%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0/
# Extracted codes: ['K10.3']
# Number of extracted codes: 1
# Extracted codes: ['K10.3']
# Number of extracted codes: 1
# Extracted codes: ['K05.30', 'K05.31', 'S02.88', 'S03.20', 'S03.22', 'S03.28']
# Number of extracted codes: 6
# Extracted codes: ['S02.5', 'S02.52', 'S02.53', 'S02.54', 'S02.56']
# Number of extracted codes: 5
# Extracted codes: ['S03.20', 'S03.21']
# Number of extracted codes: 2
# Extracted codes: []
# Number of extracted codes: 0
# Extracted codes: ['K08.1']
# Number of extracted codes: 1
# No section with '상병명' found in https://tripletclover.com/%ec%95%85%ea%b3%a8%eb%82%b4-%ea%b3%a0%ec%a0%95%ec%9a%a9-%ea%b8%88%ec%86%8d%ec%a0%9c%ea%b1%b0%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95/
# Extracted codes: ['K08.1', 'T85.6', 'Z46.3']
# Number of extracted codes: 3
# Extracted codes: ['K05.30', 'K05.31', 'S04.3', 'T85.6', 'Z96.5']
# Number of extracted codes: 5
# Extracted codes: ['K08.1', 'Z46.3']
# Number of extracted codes: 2
# Extracted codes: ['K08.1', 'Z46.3']
# Number of extracted codes: 2
# Extracted codes: ['K08.1']
# Number of extracted codes: 1
# Extracted codes: ['K08.1']
# Number of extracted codes: 1
# No section with '상병명' found in https://tripletclover.com/%ec%9e%84%ec%8b%9c%ed%8b%80%eb%8b%88-%ec%a0%81%ec%9a%a9-%ea%b8%b0%ec%a4%80-%eb%b0%8f-%ec%9e%84%ec%8b%9c-%eb%b6%80%eb%b6%84%ed%8b%80%eb%8b%88%ec%99%80-%ec%9e%84%ec%8b%9c-%ec%99%84%ec%a0%84%ed%8b%80/
# Extracted codes: ['Z46.3']
# Number of extracted codes: 1
# Extracted codes: ['Z46.3']
# Number of extracted codes: 1
# Extracted codes: ['Z46.3']
# Number of extracted codes: 1
# Extracted codes: ['Z46.3']
# Number of extracted codes: 1
# Extracted codes: ['Z46.3']
# Number of extracted codes: 1
# Extracted codes: ['G50.1', 'K07.60', 'K07.62', 'K07.63', 'K07.64', 'K07.65', 'K07.66', 'K07.68', 'K07.69', 'S03.0']
# Number of extracted codes: 10
# No section with '상병명' found in https://tripletclover.com/%ec%95%85%ea%b4%80%ec%a0%88%ed%83%88%ea%b5%ac-%eb%b9%84%ea%b4%80%ed%98%88%ec%a0%81-%ec%a0%95%eb%b3%b5%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%b9%98/
# Extracted codes: ['K07.64', 'K07.68']
# Number of extracted codes: 2
# Extracted codes: ['K07.60', 'K07.62', 'K07.63', 'K07.64', 'K07.65', 'K07.66', 'K07.68', 'K07.69', 'S03.0']
# Number of extracted codes: 9
# No section with '상병명' found in https://tripletclover.com/%ec%b8%a1%eb%91%90%ed%95%98%ec%95%85%ec%9e%a5%ec%95%a0-%eb%b6%84%ec%84%9d%ea%b2%80%ec%82%ac-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0/
# Extracted codes: ['K07.60', 'K07.61', 'K07.62', 'K07.63', 'K07.64', 'K07.65', 'K07.66', 'K07.68', 'K07.69']
# Number of extracted codes: 9
# URLs where '상병명' was not found: ['https://tripletclover.com/%ec%a0%84%eb%8b%ac%eb%a7%88%ec%b7%a8-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80%ec%9d%b4%eb%93%9c/', 'https://tripletclover.com/%ec%b9%a8%ec%9c%a4%eb%a7%88%ec%b7%a8-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80%ec%9d%b4%eb%93%9c/', 'https://tripletclover.com/%ea%b5%90%ec%9d%b5%ec%b4%ac%ec%98%81-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80%ec%9d%b4%eb%93%9c/', 'https://tripletclover.com/%ec%b9%98%ec%88%98-%eb%b3%b5%ec%a1%b0-%eb%b0%8f-%ec%83%81%eb%b3%91%eb%aa%85/', 'https://tripletclover.com/%ec%b9%98%ec%9d%80%eb%b0%95%eb%a6%ac%ec%86%8c%ed%8c%8c%ec%88%a0-%ea%b0%84%eb%8b%a8-vs-%eb%b3%b5%ec%9e%a1-%eb%b9%84%ea%b5%90-%ec%a0%95%eb%a6%ac/', 'https://tripletclover.com/%ec%b9%98%ec%9d%80%ed%8c%90%ec%a0%88%ec%a0%9c%ec%88%a0-%ec%b9%98%ea%b4%80%ed%99%95%ec%9e%a5%ec%88%a0-%ec%b9%98%ec%9d%80%ec%a0%88%ec%a0%9c%ec%88%a0-%eb%b9%84%ea%b5%90/', 'https://tripletclover.com/%ec%83%81%ea%b3%a0%ec%a0%95%ec%9e%a5%ec%b9%98%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80/', 'https://tripletclover.com/%ec%84%a4%ec%86%8c%eb%8c%80-%ec%84%b1%ed%98%95%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80/', 'https://tripletclover.com/%ed%98%91%ec%88%9c%ec%86%8c%eb%8c%80-%ec%84%a4%ec%86%8c%eb%8c%80-%ec%84%b1%ed%98%95%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0/', 'https://tripletclover.com/%ec%95%85%ea%b3%a8%eb%82%b4-%ea%b3%a0%ec%a0%95%ec%9a%a9-%ea%b8%88%ec%86%8d%ec%a0%9c%ea%b1%b0%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95/', 'https://tripletclover.com/%ec%9e%84%ec%8b%9c%ed%8b%80%eb%8b%88-%ec%a0%81%ec%9a%a9-%ea%b8%b0%ec%a4%80-%eb%b0%8f-%ec%9e%84%ec%8b%9c-%eb%b6%80%eb%b6%84%ed%8b%80%eb%8b%88%ec%99%80-%ec%9e%84%ec%8b%9c-%ec%99%84%ec%a0%84%ed%8b%80/', 'https://tripletclover.com/%ec%95%85%ea%b4%80%ec%a0%88%ed%83%88%ea%b5%ac-%eb%b9%84%ea%b4%80%ed%98%88%ec%a0%81-%ec%a0%95%eb%b3%b5%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%b9%98/', 'https://tripletclover.com/%ec%b8%a1%eb%91%90%ed%95%98%ec%95%85%ec%9e%a5%ec%95%a0-%eb%b6%84%ec%84%9d%ea%b2%80%ec%82%ac-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0/']
# Extracted codes for each URL: ['B00.2, B37.0, K05.00, K05.10, K05.11, K05.12, K05.18, K05.19, K05.22, K05.32, K12.0, K12.1, K13.1, S00.5', 'J01.00, K01.1, K01.10, K01.11, K01.12, K01.13, K01.14, K01.15, K01.163, K01.173, K02.0, K02.1, K02.2, K02.3, K02.5, K02.8, K03.00, K03.01, K03.10, K03.18, K03.2, K03.80, K04.00, K04.7, K05.1, K05.10, K05.11, K05.12, K05.13, K05.18, K05.2, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K07.6, K07.60, K07.61, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69', 'J01.00, K01.10, K01.11, K01.12, K01.13, K01.14, K01.15, K01.163, K01.173, K01.18, K04.7, K05.12, K05.13, K05.18, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K07.60, K07.61, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69', 'K02.0, K02.1, K02.2, K02.3, K02.5, K02.8, K02.9', '상병명 없음', 'K00.63, K00.68, K01.173, K02.1, K02.2, K04.00, K04.01, K04.80, S02.55', 'K00.63, K00.68, K01.173, K02.1, K02.2, K04.00, K04.01, K04.80, S02.55', '상병명 없음', 'K00.00, K00.63, K00.68, K01.163, K01.173, K01.18, K08.1, K08.88, S02.5', 'K00.29, K01.163, K01.173, K01.18, K04.80, K07.35, S02.55', '상병명 없음', 'K01.1, K04.8, K05.3, K10.0, K10.8, S04.3, T85.6', 'K02.0, K03.00, K03.10, K03.2, K03.80, K05.18, K06.00', '코드 없음', 'K02.1, K02.2, K02.8', 'K05.30, K05.31, K06.20, K07.2, K07.3, K07.4, S02.5, S02.52, S02.53, S02.54, S02.55, S02.56, S03.2, S03.20, S03.21, S03.22', 'T85.6, Z46.3', 'K02.8, K05.3, T85.6, Z46.3', 'K02.8, K05.3, T85.6, Z46.3', 'K02.1, K02.2, K02.8, K04.1, K04.9, S02.52, S02.59', 'K02.8, K05.3, T85.6, Z46.3', 'K00.68, K02.1, Z29.8', 'K02.1, K02.2, K02.8, K02.9, K03.10, K03.18', 'K03.10, K03.18, K03.80, K06.00, K06.01, K06.09, Z29.8', 'K03.10, K03.18, K03.80, K06.00, K06.01', 'K02.1, K02.2, K02.8, K02.9', 'K02.1, K02.2, K02.3, K02.8, K03.10, K03.18', 'K02.1, K02.2, K02.8, K02.9, K03.10, K03.18, T85.6, Z97.2', 'K05.00, K05.08, K05.09, K05.10, K05.18', 'K00.68, K02.1, Z29.8', '상병명 없음', 'K02.1, K02.2, K02.5, K02.8', 'T85.6', 'K04.5, K04.62, K04.7, K04.80', 'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28', 'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28', 'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28', 'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.9, S02.54, S02.55, S02.56', 'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28', 'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28', 'K04.1, K04.4, K04.62, K04.7', 'K04.5, K04.62, K04.7, K04.80', 'K02.5, K04.01, K04.09, K04.2, K04.3', 'K02.5, S02.5, S03.2, T85.6', 'K05.30, K05.31, S02.88, S03.20, S03.22, S03.28', 'K05.2, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39', 'K05.0, K05.00, K05.1, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.2, K05.20, K05.21, K05.22, K05.28, K05.29, K05.3, K05.30, K05.31, K05.32, K05.38, K05.39, K05.4, K05.5, K05.6', 'K05.0, K05.00, K05.1, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.2, K05.20, K05.21, K05.22, K05.28, K05.29, K05.3, K05.30, K05.31, K05.32, K05.38, K05.39, K05.4, K05.5, K05.6', 'K05.0, K05.00, K05.1, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.2, K05.20, K05.21, K05.22, K05.28, K05.29, K05.3, K05.30, K05.31, K05.32, K05.38, K05.39, K05.4, K05.5, K05.6', 'K05.30, K05.31, K05.38, K05.39', 'K05.30, K05.31, K05.38, K05.39', '상병명 없음', '상병명 없음', 'K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39, K05.4, K05.5, K05.6', 'K05.30, K05.31, K05.38, K05.39', 'K05.00, K05.08, K05.09, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39, K05.4, K05.5, K05.6', 'K05.30, K05.31, K05.38, K05.5', 'K05.30, K05.31, K05.38, K05.5', 'K06.0, K06.00, K06.01 ...

# %%
not_found
# Out:
# ['https://tripletclover.com/%ec%a0%84%eb%8b%ac%eb%a7%88%ec%b7%a8-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80%ec%9d%b4%eb%93%9c/',
#  'https://tripletclover.com/%ec%b9%a8%ec%9c%a4%eb%a7%88%ec%b7%a8-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80%ec%9d%b4%eb%93%9c/',
#  'https://tripletclover.com/%ea%b5%90%ec%9d%b5%ec%b4%ac%ec%98%81-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80%ec%9d%b4%eb%93%9c/',
#  'https://tripletclover.com/%ec%b9%98%ec%88%98-%eb%b3%b5%ec%a1%b0-%eb%b0%8f-%ec%83%81%eb%b3%91%eb%aa%85/',
#  'https://tripletclover.com/%ec%b9%98%ec%9d%80%eb%b0%95%eb%a6%ac%ec%86%8c%ed%8c%8c%ec%88%a0-%ea%b0%84%eb%8b%a8-vs-%eb%b3%b5%ec%9e%a1-%eb%b9%84%ea%b5%90-%ec%a0%95%eb%a6%ac/',
#  'https://tripletclover.com/%ec%b9%98%ec%9d%80%ed%8c%90%ec%a0%88%ec%a0%9c%ec%88%a0-%ec%b9%98%ea%b4%80%ed%99%95%ec%9e%a5%ec%88%a0-%ec%b9%98%ec%9d%80%ec%a0%88%ec%a0%9c%ec%88%a0-%eb%b9%84%ea%b5%90/',
#  'https://tripletclover.com/%ec%83%81%ea%b3%a0%ec%a0%95%ec%9e%a5%ec%b9%98%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80/',
#  'https://tripletclover.com/%ec%84%a4%ec%86%8c%eb%8c%80-%ec%84%b1%ed%98%95%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0%ec%a4%80-%ec%99%84%eb%b2%bd-%ea%b0%80/',
#  'https://tripletclover.com/%ed%98%91%ec%88%9c%ec%86%8c%eb%8c%80-%ec%84%a4%ec%86%8c%eb%8c%80-%ec%84%b1%ed%98%95%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0/',
#  'https://tripletclover.com/%ec%95%85%ea%b3%a8%eb%82%b4-%ea%b3%a0%ec%a0%95%ec%9a%a9-%ea%b8%88%ec%86%8d%ec%a0%9c%ea%b1%b0%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95/',
#  'https://tripletclover.com/%ec%9e%84%ec%8b%9c%ed%8b%80%eb%8b%88-%ec%a0%81%ec%9a%a9-%ea%b8%b0%ec%a4%80-%eb%b0%8f-%ec%9e%84%ec%8b%9c-%eb%b6%80%eb%b6%84%ed%8b%80%eb%8b%88%ec%99%80-%ec%9e%84%ec%8b%9c-%ec%99%84%ec%a0%84%ed%8b%80/',
#  'https://tripletclover.com/%ec%95%85%ea%b4%80%ec%a0%88%ed%83%88%ea%b5%ac-%eb%b9%84%ea%b4%80%ed%98%88%ec%a0%81-%ec%a0%95%eb%b3%b5%ec%88%a0-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%b9%98/',
#  'https://tripletclover.com/%ec%b8%a1%eb%91%90%ed%95%98%ec%95%85%ec%9e%a5%ec%95%a0-%eb%b6%84%ec%84%9d%ea%b2%80%ec%82%ac-%ec%a0%81%ec%9a%a9-%ea%b0%80%eb%8a%a5-%ec%83%81%eb%b3%91%eb%aa%85-%eb%b0%8f-%ec%82%b0%ec%a0%95-%ea%b8%b0/']

# %%
extracted_codes
# Out:
# ['B00.2, B37.0, K05.00, K05.10, K05.11, K05.12, K05.18, K05.19, K05.22, K05.32, K12.0, K12.1, K13.1, S00.5',
#  'J01.00, K01.1, K01.10, K01.11, K01.12, K01.13, K01.14, K01.15, K01.163, K01.173, K02.0, K02.1, K02.2, K02.3, K02.5, K02.8, K03.00, K03.01, K03.10, K03.18, K03.2, K03.80, K04.00, K04.7, K05.1, K05.10, K05.11, K05.12, K05.13, K05.18, K05.2, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K07.6, K07.60, K07.61, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69',
#  'J01.00, K01.10, K01.11, K01.12, K01.13, K01.14, K01.15, K01.163, K01.173, K01.18, K04.7, K05.12, K05.13, K05.18, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K07.60, K07.61, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69',
#  'K02.0, K02.1, K02.2, K02.3, K02.5, K02.8, K02.9',
#  '상병명 없음',
#  'K00.63, K00.68, K01.173, K02.1, K02.2, K04.00, K04.01, K04.80, S02.55',
#  'K00.63, K00.68, K01.173, K02.1, K02.2, K04.00, K04.01, K04.80, S02.55',
#  '상병명 없음',
#  'K00.00, K00.63, K00.68, K01.163, K01.173, K01.18, K08.1, K08.88, S02.5',
#  'K00.29, K01.163, K01.173, K01.18, K04.80, K07.35, S02.55',
#  '상병명 없음',
#  'K01.1, K04.8, K05.3, K10.0, K10.8, S04.3, T85.6',
#  'K02.0, K03.00, K03.10, K03.2, K03.80, K05.18, K06.00',
#  '코드 없음',
#  'K02.1, K02.2, K02.8',
#  'K05.30, K05.31, K06.20, K07.2, K07.3, K07.4, S02.5, S02.52, S02.53, S02.54, S02.55, S02.56, S03.2, S03.20, S03.21, S03.22',
#  'T85.6, Z46.3',
#  'K02.8, K05.3, T85.6, Z46.3',
#  'K02.8, K05.3, T85.6, Z46.3',
#  'K02.1, K02.2, K02.8, K04.1, K04.9, S02.52, S02.59',
#  'K02.8, K05.3, T85.6, Z46.3',
#  'K00.68, K02.1, Z29.8',
#  'K02.1, K02.2, K02.8, K02.9, K03.10, K03.18',
#  'K03.10, K03.18, K03.80, K06.00, K06.01, K06.09, Z29.8',
#  'K03.10, K03.18, K03.80, K06.00, K06.01',
#  'K02.1, K02.2, K02.8, K02.9',
#  'K02.1, K02.2, K02.3, K02.8, K03.10, K03.18',
#  'K02.1, K02.2, K02.8, K02.9, K03.10, K03.18, T85.6, Z97.2',
#  'K05.00, K05.08, K05.09, K05.10, K05.18',
#  'K00.68, K02.1, Z29.8',
#  '상병명 없음',
#  'K02.1, K02.2, K02.5, K02.8',
#  'T85.6',
#  'K04.5, K04.62, K04.7, K04.80',
#  'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28',
#  'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28',
#  'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28',
#  'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.9, S02.54, S02.55, S02.56',
#  'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28',
#  'K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28',
#  'K04.1, K04.4, K04.62, K04.7',
#  'K04.5, K04.62, K04.7, K04.80',
#  'K02.5, K04.01, K04.09, K04.2, K04.3',
#  'K02.5, S02.5, S03.2, T85.6',
#  'K05.30, K05.31, S02.88, S03.20, S03.22, S03.28',
#  'K05.2, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39',
#  'K05.0, K05.00, K05.1, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.2, K05.20, K05.21, K05.22, K05.28, K05.29, K05.3, K05.30, K05.31, K05.32, K05.38, K05.39, K05.4, K05.5, K05.6',
#  'K05.0, K05.00, K05.1, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.2, K05.20, K05.21, K05.22, K05.28, K05.29, K05.3, K05.30, K05.31, K05.32, K05.38, K05.39, K05.4, K05.5, K05.6',
#  'K05.0, K05.00, K05.1, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.2, K05.20, K05.21, K05.22, K05.28, K05.29, K05.3, K05.30, K05.31, K05.32, K05.38, K05.39, K05.4, K05.5, K05.6',
#  'K05.30, K05.31, K05.38, K05.39',
#  'K05.30, K05.31, K05.38, K05.39',
#  '상병명 없음',
#  '상병명 없음',
#  'K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39, K05.4, K05.5, K05.6',
#  'K05.30, K05.31, K05.38, K05.39',
#  'K05.00, K05.08, K05.09, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39, K05.4, K05.5, K05.6',
#  'K05.30, K05.31, K05.38, K05.5',
#  'K05.30, K05.31, K05.38, K05.5',
#  'K06.0, K06.00, K06.01, K06.1, K06.10, K06.18, K06.2, K06.8, K06.9, K08.20, M26.09, T81.8',
#  'K06.8, K06.9, K08.20, M26.09, T81.8',
#  'K10.0, K10.8',
#  'K00.10, K00.11, K00.12, K00.19, K01.18',
#  'S01.51, S01.52, S01.53, S01.54',
#  'K04.7, K05.20, K10.2, K12.2',
#  'K00.20, K00.44, K03.4, K03.5, K07.3, S02.5',
#  'K01.0, K01.10, K01.11, K01.12, K01.13, K01.14, K01.15, K01.163, K01.169, K01.173, K01.179, K01.18, K01.19',
#  'K00.1, K00.10, K00.11, K00.12, K00.19, K00.2, K00.63, K01.163, K02.2, K03.5, K08.3, S02.5, S02.55, S02.56, S02.57, S02.59, S03.2, S03.21, S03.22, S03.28',
#  'K01.0, K01.10, K01.11, K01.12, K01.13, K01.14, K01.15, K01.163, K01.169, K01.173, K01.179, K01.18, K01.19, K07.35',
#  '상병명 없음',
#  '상병명 없음',
#  'K01.163, K01.173, K01.18, K01.19, K04.7, K04.80, K05.20, K05.31, K08.3, K10.3, S02.55, S02.56, S02.57, Z48.0',
#  'K04.7, K04.80, K04.81, K04.82, K04.89, K05.20, K10.2, K12.2, Z48.0',
#  'D10.3, K04.7, K05.20, K10.2, K10.3, K12.2',
#  'Y60.0',
#  'K01.0, K01.10, K01.11, K01.12, K01.13, K01.14, K01.15, K01.163, K01.169, K01.173, K01.179, K01.18, K01.19',
#  'K00.63, K00.68, K00.69, K02.8, K03.5, K04.7',
#  'S01.4, S01.40, S01.41, S01.42, S01.48, S01.50',
#  'K02.2, K02.8, K06.18, K06.19, S02.54, S02.56',
#  'K04.80, K04.81, K04.82, K04.89',
#  'K04.5, K04.62, K04.7, K04.80, K04.81, K04.82',
#  'K04.5, K04.62, K04.7, K04.80, K04.9, S03.22',
#  'K05.11, K05.30, K05.31, K05.38, K06.10, K06.18, K06.19',
#  'K00.68, K02.1, K05.22, K06.18',
#  'K08.81',
#  '상병명 없음',
#  'K10.3',
#  'K10.3',
#  'K05.30, K05.31, S02.88, S03.20, S03.22, S03.28',
#  'S02.5, S02.52, S02.53, S02.54, S02.56',
#  'S03.20, S03.21',
#  '코드 없음',
#  'K08.1',
#  '상병명 없음',
#  'K08.1, T85.6, Z46.3',
#  'K05.30, K05.31, S04.3, T85.6, Z96.5',
#  'K08.1, Z46.3',
#  'K08.1, Z46.3',
#  'K08.1',
#  'K08.1',
#  '상병명 없음',
#  'Z46.3',
#  'Z46.3',
#  'Z46.3',
#  'Z46.3',
#  'Z46.3',
#  'G50.1, K07.60, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69, S03.0',
#  '상병명 없음',
#  'K07.64, K07.68',
#  'K07.60, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69, S03.0',
#  '상병명 없음',
#  'K07.60, K07.61, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69']

# %%
# '코드' 열에 상위 10개의 크롤링 결과만 추가
df_action["코드"] = extracted_codes  # 인덱스 0~9까지에 해당하는 10개 행에만 추가

df_action.head(10)
# Out:
#      보험 청구 Category         세부 청구 항목 (키워드)  \
# 1   1. 청구 기초 및 기본진료         구내염처치, 단순염증 처치
# 2   1. 청구 기초 및 기본진료           기본진료 종류 및 상병
# 3   1. 청구 기초 및 기본진료        기본진료시 항생제 처방 상병
# 4   1. 청구 기초 및 기본진료  상세불명 vs 기타 명시된 상병명 차이
# 5   1. 청구 기초 및 기본진료                   전달마취
# 6   1. 청구 기초 및 기본진료                    치근단
# 7   1. 청구 기초 및 기본진료              치근단 동시 촬영
# 8   1. 청구 기초 및 기본진료                   침윤마취
# 9   1. 청구 기초 및 기본진료                파노라마 촬영
# 10  1. 청구 기초 및 기본진료               CT (치과용)
#
# URL  (tripletclover.com)  \
# 1   https://tripletclover.com/%ea%b5%ac%eb%82%b4%e...
# 2   https://tripletclover.com/%ea%b8%b0%eb%b3%b8%e...
# 3   https://tripletclover.com/%ea%b8%b0%eb%b3%b8-%...
# 4   https://tripletclover.com/%ec%83%81%ec%84%b8%e...
# 5   https://tripletclover.com/%ec%a0%84%eb%8b%ac%e...
# 6   https://tripletclover.com/%ec%b9%98%ea%b7%bc%e...
# 7   https://tripletclover.com/%ec%b9%98%ea%b7%bc%e...
# 8   https://tripletclover.com/%ec%b9%a8%ec%9c%a4%e...
# 9   https://tripletclover.com/%ed%8c%8c%eb%85%b8%e...
# 10  https://tripletclover.com/%ec%b9%98%ea%b3%bc-c...
#
#                                                    코드 상병명 없음 휴먼 체크
# 1   B00.2, B37.0, K05.00, K05.10, K05.11, K05.12, ...
# 2   J01.00, K01.1, K01.10, K01.11, K01.12, K01.13,...
# 3   J01.00, K01.10, K01.11, K01.12, K01.13, K01.14...
# 4     K02.0, K02.1, K02.2, K02.3, K02.5, K02.8, K02.9
# 5                                              상병명 없음           완료
# 6   K00.63, K00.68, K01.173, K02.1, K02.2, K04.00,...
# 7   K00.63, K00.68, K01.173, K02.1, K02.2, K04.00,...
# 8                                              상병명 없음           완료
# 9   K00.00, K00.63, K00.68, K01.163, K01.173, K01....
# 10  K00.29, K01.163, K01.173, K01.18, K04.80, K07....

# %% [markdown]
# ### '코드' 열 전체를 스프레드시트에 업데이트

# %%
# 데이터프레임의 전체 행에 맞는 셀 범위 설정
num_rows = len(df_action)  # 데이터프레임의 총 행 수
cell_range = f"D2:D{num_rows + 1}"  # D2부터 전체 행에 해당하는 범위 지정

# '코드' 열의 전체 값을 추출
code_column_values = df_action["코드"].tolist()

# 스프레드시트의 '코드' 열을 업데이트
sheet_action.update(cell_range, [[code] for code in code_column_values])
# Out:
# /var/folders/dn/kpsvhr056zz6gvcnmgrkklzr0000gn/T/ipykernel_22177/3753301064.py:9: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet_action.update(cell_range, [[code] for code in code_column_values])
# {'spreadsheetId': '1PzFuHuF2DvMPdSI-TK4Kq5LjPwyGzIxH3Q0Drnqft20',
#  'updatedRange': "'행위별 Category'!D2:D112",
#  'updatedRows': 111,
#  'updatedColumns': 1,
#  'updatedCells': 111}

# %% [markdown]
# ---
# ## 후처리
# ### 상병 Category 코드에 존재하는 코드들만 추가

# %%
temp = df_action["코드"].tolist()

sheet_code = doc.worksheet("상병 Category의 사본")

df_code = pd.DataFrame(sheet_code.get_all_values())

# 첫 번째 행을 컬럼명으로 설정하고 나머지 데이터로 변환
df_code.rename(columns=df_code.iloc[0], inplace=True)
df_code.drop(df_code.index[0], inplace=True)

df_code
# Out:
# 불완전 상병명                      \
# 1       K00.~                           치아 발육 및 맹출 장애
# 2      K00.0~                                     무치증
# 3      K00.00                                   부분무치증     1. 청구 기초 및 기본진료
# 4      K00.01                                   완전무치증
# 5      K00.1~                                     과잉치
# ..        ...                                     ... ..              ...
# 201    기타 상병명
# 202       R12                                     속쓰림
# 203     T85.6  기타 명시된 내부 인공삽입장치, 삽입물 및 이식편의 기계적 합병증\t     1. 청구 기초 및 기본진료
# 204     Z29.8                           기타 명시된 예방적 조치               2. 보존
# 205     Z46.3                        치과보철 장치의 부착 및 조정               2. 보존
#
#
# 1
# 2
# 3    파노라마 촬영
# 4
# 5
# ..       ...
# 201
# 202
# Bur
# 204      실란트
# 205  보철물 재부착
#
# [205 rows x 5 columns]

# %%
# df_code의 '불완전 상병 코드'를 리스트로 변환
code_list = df_code["불완전 상병 코드"].tolist()


# temp 리스트에서 각 코드 리스트를 순회하며 일치하는 코드만 남기기 위한 함수 정의
def filter_valid_codes(codes):
    # '상병명 없음'과 '코드 없음'을 그대로 유지
    if codes in ["상병명 없음", "코드 없음"]:
        return codes
    # codes가 문자열인지 확인하고, 쉼표로 구분된 문자열이라면 리스트로 변환
    if isinstance(codes, str):
        codes = codes.split(",")
    # 각 코드에 대해 공백 제거 후 필터링
    return ", ".join([code.strip() for code in codes if code.strip() in code_list])


# temp 리스트에 있는 각 항목에 대해 필터링 적용
filtered_temp = [filter_valid_codes(i) for i in temp]

# 필터링된 결과 출력
for i in filtered_temp:
    print(i)
# Out:
# B00.2, K05.00, K05.10, K05.11, K05.12, K05.18, K05.19, K05.22, K05.32, K12.0, K12.1, K13.1, S00.5
# K02.0, K02.1, K02.2, K02.3, K02.5, K02.8, K03.00, K03.01, K03.10, K03.18, K03.2, K03.80, K04.00, K04.7, K05.10, K05.11, K05.12, K05.13, K05.18, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K07.60, K07.61, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69
# K01.18, K04.7, K05.12, K05.13, K05.18, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K07.60, K07.61, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69
# K02.0, K02.1, K02.2, K02.3, K02.5, K02.8
# 상병명 없음
# K00.63, K00.68, K02.1, K02.2, K04.00, K04.01, K04.80, S02.55
# K00.63, K00.68, K02.1, K02.2, K04.00, K04.01, K04.80, S02.55
# 상병명 없음
# K00.00, K00.63, K00.68, K01.18, K08.1, K08.88
# K00.29, K01.18, K04.80, K07.35, S02.55
# 상병명 없음
# K10.0, K10.8, S04.3, T85.6
# K02.0, K03.00, K03.10, K03.2, K03.80, K05.18, K06.00
# 코드 없음
# K02.1, K02.2, K02.8
# K05.30, K05.31, K06.20, S02.52, S02.53, S02.54, S02.55, S02.56, S03.20, S03.21, S03.22
# T85.6, Z46.3
# K02.8, T85.6, Z46.3
# K02.8, T85.6, Z46.3
# K02.1, K02.2, K02.8, K04.1, K04.9, S02.52, S02.59
# K02.8, T85.6, Z46.3
# K00.68, K02.1, Z29.8
# K02.1, K02.2, K02.8, K03.10, K03.18
# K03.10, K03.18, K03.80, K06.00, K06.01, Z29.8
# K03.10, K03.18, K03.80, K06.00, K06.01
# K02.1, K02.2, K02.8
# K02.1, K02.2, K02.3, K02.8, K03.10, K03.18
# K02.1, K02.2, K02.8, K03.10, K03.18, T85.6
# K05.00, K05.08, K05.09, K05.10, K05.18
# K00.68, K02.1, Z29.8
# 상병명 없음
# K02.1, K02.2, K02.5, K02.8
# T85.6
# K04.5, K04.62, K04.7, K04.80
# K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28
# K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28
# K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28
# K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.9, S02.54, S02.55, S02.56
# K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28
# K02.5, K04.01, K04.1, K04.2, K04.3, K04.4, K04.5, K04.62, K04.7, K04.80, K04.9, S02.54, S02.55, S02.56, S03.20, S03.28
# K04.1, K04.4, K04.62, K04.7
# K04.5, K04.62, K04.7, K04.80
# K02.5, K04.01, K04.09, K04.2, K04.3
# K02.5, T85.6
# K05.30, K05.31, S02.88, S03.20, S03.22, S03.28
# K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39
# K05.00, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39, K05.5, K05.6
# K05.00, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39, K05.5, K05.6
# K05.00, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39, K05.5, K05.6
# K05.30, K05.31, K05.38, K05.39
# K05.30, K05.31, K05.38, K05.39
# 상병명 없음
# 상병명 없음
# K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39, K05.5, K05.6
# K05.30, K05.31, K05.38, K05.39
# K05.00, K05.08, K05.09, K05.10, K05.11, K05.12, K05.13, K05.18, K05.19, K05.20, K05.21, K05.22, K05.28, K05.29, K05.30, K05.31, K05.32, K05.38, K05.39, K05.5, K05.6
# K05.30, K05.31, K05.38, K05.5
# K05.30, K05.31, K05.38, K05.5
# K06.00, K06.01, K06.10, K06.18
#
# K10.0, K10.8
# K00.10, K00.11, K00.12, K00.19, K01.18
# S01.51, S01.52, S01.53, S01.54
# K04.7, K05.20, K10.2, K12.2
# K00.44, K03.5
# K01.0, K01.18, K01.19
# K00.10, K00.11, K00.12, K00.19, K00.63, K02.2, K03.5, K08.3, S02.55, S02.56, S02.57, S02.59, S03.21, S03.22, S03.28
# K01.0, K01.18, K01.19, K07.35
# 상병명 없음
# 상병명 없음
# K01.18, K01.19, K04.7, K04.80, K05.20, K05.31, K08.3, K10.3, S02.55, S02.56, S02.57
# K04.7, K04.80, K04.81, K04.82, K04.89, K05.20, K10.2, K12.2
# D10.3, K04.7, K05.20, K10.2, K10.3, K12.2
#
# K01.0, K01.18, K01.19
# K00.63, K00.68, K00.69, K02.8, K03.5, K04.7
# S01.50
# K02.2, K02.8, K06.18, K06.19, S02.54, S02.56
# K04.80, K04.81, K04.82, K04.89
# K04.5, K04.62, K04.7, K04.80, K04.81, K04.82
# K04.5, K04.62, K04.7, K04.80, K04.9, S03.22
# K05.11, K05.30, K05.31, K05.38, K06.10, K06.18, K06.19
# K00.68, K02.1, K05.22, K06.18
# K08.81
# 상병명 없음
# K10.3
# K10.3
# K05.30, K05.31, S02.88, S03.20, S03.22, S03.28
# S02.52, S02.53, S02.54, S02.56
# S03.20, S03.21
# 코드 없음
# K08.1
# 상병명 없음
# K08.1, T85.6, Z46.3
# K05.30, K05.31, S04.3, T85.6
# K08.1, Z46.3
# K08.1, Z46.3
# K08.1
# K08.1
# 상병명 없음
# Z46.3
# Z46.3
# Z46.3
# Z46.3
# Z46.3
# K07.60, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69, S03.0
# 상병명 없음
# K07.64, K07.68
# K07.60, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69, S03.0
# 상병명 없음
# K07.60, K07.61, K07.62, K07.63, K07.64, K07.65, K07.66, K07.68, K07.69

# %%
# 데이터프레임의 전체 행에 맞는 셀 범위 설정
num_rows = len(df_action)  # 데이터프레임의 총 행 수
cell_range = f"D2:D{num_rows + 1}"  # D2부터 전체 행에 해당하는 범위 지정

# '코드' 열의 전체 값을 추출
code_column_values = filtered_temp

# 스프레드시트의 '코드' 열을 업데이트
sheet_action.update(cell_range, [[code] for code in filtered_temp])
# Out:
# /var/folders/dn/kpsvhr056zz6gvcnmgrkklzr0000gn/T/ipykernel_22177/790274438.py:9: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   sheet_action.update(cell_range, [[code] for code in filtered_temp])
# {'spreadsheetId': '1PzFuHuF2DvMPdSI-TK4Kq5LjPwyGzIxH3Q0Drnqft20',
#  'updatedRange': "'행위별 Category'!D2:D112",
#  'updatedRows': 111,
#  'updatedColumns': 1,
#  'updatedCells': 111}
